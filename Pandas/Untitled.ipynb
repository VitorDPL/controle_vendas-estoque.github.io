# %%
import pandas as pd

# %%
df_vendas= pd.read_csv('vendas.csv')
df_estoque= pd.read_csv('estoque.csv')
mesclado= df_vendas.merge(df_estoque, on='ref')

# display(df_vendas)
# display(df_estoque)

mesclado= mesclado.rename(columns= {'quantidade' : 'quantidade vendida'})
mesclado= mesclado.rename(columns= {'quantidade_pecas' : 'quantidade em estoque'})

display(mesclado)
# Out:
#       id   ref  number  quantidade vendida  venda  data_venda    tipo_peca_x  \
# 0    104  1111      42                   5  venda  18/12/2023  Vestido Curto
# 1    104  1111      42                   5  venda  18/12/2023  Vestido Curto
# 2    104  1111      42                   5  venda  18/12/2023  Vestido Curto
# 3    104  1111      42                   5  venda  18/12/2023  Vestido Curto
# 4    104  1111      42                   5  venda  18/12/2023  Vestido Curto
# ..   ...   ...     ...                 ...    ...         ...            ...
# 113  121  4111      62                   6  venda  19/12/2023  Vestido Curto
# 114  121  4111      62                   6  venda  19/12/2023  Vestido Curto
# 115  121  4111      62                   6  venda  19/12/2023  Vestido Curto
# 116  121  4111      62                   6  venda  19/12/2023  Vestido Curto
# 117  121  4111      62                   6  venda  19/12/2023  Vestido Curto
#
# ...
